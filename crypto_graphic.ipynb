# %% [markdown]
# <a href="https://colab.research.google.com/github/esraayigit/C-kodlarim/blob/main/crypto_graphic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
bitcoin=yf.download("btc-usd","2022-01-01","2024-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
type(bitcoin)
# Out:
# pandas.core.frame.DataFrame

# %%
bitcoin["Close"].plot(figsize=(16,8))
# Out:
# <Axes: xlabel='Date'>

# %%
def coingrafik(isim,tarih,tarih2):
  isim=isim+"-usd"
  coin=yf.download(isim,tarih,tarih2)
  coin["Close"].plot(figsize=(16,8))
  return isim

# %%
coingrafik("doge","2018-01-01","2024-12-20")
# Out:
# [*********************100%***********************]  1 of 1 completed
# 'doge-usd'
